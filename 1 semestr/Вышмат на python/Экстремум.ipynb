# %%
import numpy as np
# cos^3(f(x))

def pr(name, x):
    p = np.cos(name(x)) ** 3
    return p


p1 = pr(np.sin, 0)

print(p1)
y.subs(x, 2)
# Out:
# 1.0
# 13

# %%
from sympy import *

x = Symbol('x')
f = x**3 + x

y = diff(f, x, 1)

print(y)
# Out:
# 3*x**2 + 1

# %%
from sympy import *
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize

# 0.5 * x^2 + e^x + 2x  - производная ф равна 2 ГДЕЕ?????????

x = np.linspace(-5, 5, 100)
plt.plot(x, 0.5 * x ** 2 + np.exp(x) + 2*x)
plt.grid()

p = x + np.exp(x) 
plt.plot(x, p)

def f(x):
    return x + np.exp(x)
    
r = optimize.brentq(f, -2, 0)
print(r)
# Out:
# -0.5671432904098384

# %%
def f(x):
    return (x-2) ** 2 + 1

minimum = optimize.fmin(f, 1, full_output = True, disp=False)

print(minimum[1])
# Out:
# 1.0

# %%
# Найдите точку минимума функции    y = x^3 - 30x^2 + 17

from sympy import *
import numpy as np

def f(x):
    return x**3 - 30*x**2 + 17

x = np.linspace(-10, 10, 100)

minimum= optimize.fmin(f, 1, full_output = False, disp=False)

print(minimum)


plt.plot(x, x**3 - 30*x**2 + 17)
p = 3*x**2 - 60*x

plt.plot(x, p)
plt.grid()
# Out:
# [20.]
